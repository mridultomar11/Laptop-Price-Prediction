# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('file2.csv')
df.head()
# Out:
#    Unnamed: 0  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
#                                                                                                        Title  \
# 0  Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# 1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...
# 2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...
# 3  ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# 4  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
#
#    Rating  Price                           Processor            RAM  \
# 0  4.1     25685  Intel Celeron Dual Core Processor   8 GB DDR4 RAM
# 1  4.4     51990  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 2  4.2     38990  Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\mridu\AppData\Local\Temp\ipykernel_10152\3462665596.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Rating', 'Price', 'Processor', 'RAM',
#        'Display Size', 'Storage Capacity', 'Brand', 'SSD_Availability',
#        'SSD_Capacity', 'Ram', 'Ram_Type', 'Display_Size'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#                                                                                                        Title  \
# 0  Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# 1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...
# 2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...
# 3  ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# 4  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
#
#    Rating  Price                           Processor            RAM  \
# 0  4.1     25685  Intel Celeron Dual Core Processor   8 GB DDR4 RAM
# 1  4.4     51990  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 2  4.2     38990  Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# 3  4.1     23990  Intel Celeron Dual Core Processor   4 GB DDR4 RAM
# ...

# %%
df[df['SSD_Availability']=='NO']
# Out:
#                                                                                                          Title  \
# 48   ASUS Chromebook Flip Touch Celeron Dual Core - (4 GB/32 GB EMMC Storage/Chrome OS) C214MA-BU0704 Chrom...
# 156  HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11a-na0006MU Chromebook
# 157  ASUS EeeBook 12 Celeron Dual Core - (4 GB/64 GB EMMC Storage/Windows 11 Home) E210MA-GJ012W Thin and L...
# 238  ASUS Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C523NA-BR0300| C523NA-BR0476 C...
# 415  DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop
# 542  ASUS Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C423NA-EC0521 Chromebook
# 582  Lenovo Ryzen 3 Dual Core 3250U - (4 GB/1 TB HDD/Windows 10 Home) V15 -ADA Laptop
# 606  Lenovo Intel Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) 14IGL05 Thin and Light Laptop
# ...

# %%
w=list(df['SSD_Availability'].values)
l=[]
for i in w:
    if i=='YES':
        l.append(0)
    else:
        l.append(64)

# %%
df['EMMC_Storage(in_GB)']=l

# %%
df.at[48,'EMMC_Storage(in_GB)']=32
df.at[415,'EMMC_Storage(in_GB)']=0
df.at[582,'EMMC_Storage(in_GB)']=0
df.at[686,'EMMC_Storage(in_GB)']=0

df.at[695,'EMMC_Storage(in_GB)']=0
df.at[745,'EMMC_Storage(in_GB)']=0
df.at[772,'EMMC_Storage(in_GB)']=0
df.at[774,'EMMC_Storage(in_GB)']=0

df.at[825,'EMMC_Storage(in_GB)']=0
df.at[856,'EMMC_Storage(in_GB)']=0
df.at[894,'EMMC_Storage(in_GB)']=0
df.at[904,'EMMC_Storage(in_GB)']=0
df.at[905,'EMMC_Storage(in_GB)']=0


df.at[909,'EMMC_Storage(in_GB)']=0
df.at[912,'EMMC_Storage(in_GB)']=0
df.at[919,'EMMC_Storage(in_GB)']=0
df.at[920,'EMMC_Storage(in_GB)']=0
df.at[934,'EMMC_Storage(in_GB)']=0

df.at[944,'EMMC_Storage(in_GB)']=0
df.at[955,'EMMC_Storage(in_GB)']=0
df.at[973,'EMMC_Storage(in_GB)']=0
df.at[976,'EMMC_Storage(in_GB)']=0
df.at[979,'EMMC_Storage(in_GB)']=0

df.at[980,'EMMC_Storage(in_GB)']=0
df.at[982,'EMMC_Storage(in_GB)']=0

# %%
df[df['SSD_Availability']=='NO']
# Out:
#                                                                                                          Title  \
# 48   ASUS Chromebook Flip Touch Celeron Dual Core - (4 GB/32 GB EMMC Storage/Chrome OS) C214MA-BU0704 Chrom...
# 156  HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11a-na0006MU Chromebook
# 157  ASUS EeeBook 12 Celeron Dual Core - (4 GB/64 GB EMMC Storage/Windows 11 Home) E210MA-GJ012W Thin and L...
# 238  ASUS Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C523NA-BR0300| C523NA-BR0476 C...
# 415  DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop
# 542  ASUS Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C423NA-EC0521 Chromebook
# 582  Lenovo Ryzen 3 Dual Core 3250U - (4 GB/1 TB HDD/Windows 10 Home) V15 -ADA Laptop
# 606  Lenovo Intel Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) 14IGL05 Thin and Light Laptop
# ...

# %%
df.shape
# Out:
# (984, 14)

# %%
df.duplicated().sum()
# Out:
# 170

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
hdd=[]
for i in range(814):
    hdd.append(0)

# %%
df['HDD_Storage(in_GB)']=hdd

# %%
df.at[415,'HDD_Storage(in_GB)']=1024
df.at[582,'HDD_Storage(in_GB)']=1024
df.at[686,'HDD_Storage(in_GB)']=1024

df.at[695,'HDD_Storage(in_GB)']=1024
df.at[745,'HDD_Storage(in_GB)']=1024
df.at[772,'HDD_Storage(in_GB)']=1024
df.at[774,'HDD_Storage(in_GB)']=1024

df.at[825,'HDD_Storage(in_GB)']=1024
df.at[856,'HDD_Storage(in_GB)']=1024
df.at[894,'HDD_Storage(in_GB)']=1024
df.at[904,'HDD_Storage(in_GB)']=1024
df.at[905,'HDD_Storage(in_GB)']=1024


df.at[909,'HDD_Storage(in_GB)']=1024
df.at[912,'HDD_Storage(in_GB)']=1024
df.at[919,'HDD_Storage(in_GB)']=1024
df.at[920,'HDD_Storage(in_GB)']=1024
df.at[934,'HDD_Storage(in_GB)']=1024

df.at[944,'HDD_Storage(in_GB)']=1024
df.at[955,'HDD_Storage(in_GB)']=1024
df.at[973,'HDD_Storage(in_GB)']=1024
df.at[976,'HDD_Storage(in_GB)']=1024
df.at[979,'HDD_Storage(in_GB)']=1024

df.at[980,'HDD_Storage(in_GB)']=2048
df.at[982,'HDD_Storage(in_GB)']=1024

# %%
df.at[9,'HDD_Storage(in_GB)']=1024
df.at[17,'HDD_Storage(in_GB)']=1024
df.at[85,'HDD_Storage(in_GB)']=1024
df.at[93,'HDD_Storage(in_GB)']=1024
df.at[113,'HDD_Storage(in_GB)']=1024
df.at[135,'HDD_Storage(in_GB)']=1024
df.at[137,'HDD_Storage(in_GB)']=1024
df.at[160,'HDD_Storage(in_GB)']=1024
df.at[209,'HDD_Storage(in_GB)']=512
df.at[294,'HDD_Storage(in_GB)']=1024
df.at[322,'HDD_Storage(in_GB)']=1024
df.at[368,'HDD_Storage(in_GB)']=1024
df.at[443,'HDD_Storage(in_GB)']=1024
df.at[447,'HDD_Storage(in_GB)']=1024
df.at[464,'HDD_Storage(in_GB)']=1024
df.at[517,'HDD_Storage(in_GB)']=1024
df.at[553,'HDD_Storage(in_GB)']=1024

# %%
df.at[561,'HDD_Storage(in_GB)']=1024
df.at[594,'HDD_Storage(in_GB)']=1024
df.at[642,'HDD_Storage(in_GB)']=1024
df.at[644,'HDD_Storage(in_GB)']=1024
df.at[659,'HDD_Storage(in_GB)']=1024
df.at[672,'HDD_Storage(in_GB)']=1024
df.at[674,'HDD_Storage(in_GB)']=512
df.at[735,'HDD_Storage(in_GB)']=1024
df.at[746,'HDD_Storage(in_GB)']=1024
df.at[816,'HDD_Storage(in_GB)']=1024
df.at[829,'HDD_Storage(in_GB)']=1024
df.at[830,'HDD_Storage(in_GB)']=1024
df.at[835,'HDD_Storage(in_GB)']=1024
df.at[925,'HDD_Storage(in_GB)']=1024
df.at[935,'HDD_Storage(in_GB)']=1024
df.at[962,'HDD_Storage(in_GB)']=1024
df.at[967,'HDD_Storage(in_GB)']=1024
df.at[970,'HDD_Storage(in_GB)']=1024

# %%
df.columns
# Out:
# Index(['Title', 'Rating', 'Price', 'Processor', 'RAM', 'Display Size',
#        'Storage Capacity', 'Brand', 'SSD_Availability', 'SSD_Capacity', 'Ram',
#        'Ram_Type', 'Display_Size', 'EMMC_Storage(in_GB)',
#        'HDD_Storage(in_GB)'],
#       dtype='object')

# %%
df.drop('SSD_Availability',axis=1,inplace=True)
df.head()
# Out:
#                                                                                                        Title  \
# 0  Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# 1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...
# 2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...
# 3  ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# 4  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
#
#    Rating    Price                           Processor            RAM  \
# 0  4.1     25685.0  Intel Celeron Dual Core Processor   8 GB DDR4 RAM
# 1  4.4     51990.0  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 2  4.2     38990.0  Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# ...

# %%
df['Processor'].value_counts()
# Out:
# AMD Ryzen 7 Octa Core Processor                                                         87
# Intel Core i5 Processor (12th Gen)                                                      77
# Intel Core i7 Processor (12th Gen)                                                      71
# AMD Ryzen 5 Hexa Core Processor                                                         68
# Intel Core i5 Processor (11th Gen)                                                      65
# Intel Core i3 Processor (11th Gen)                                                      64
# Intel Core i5 Processor (10th Gen)                                                      28
# AMD Ryzen 9 Octa Core Processor                                                         24
# Intel Core i3 Processor (10th Gen)                                                      23
# Intel Core i7 Processor (11th Gen)                                                      21
# ...

# %%
df['Processor']=df['Processor'].replace('Processor: Intel i5-1235U (Base- 3.30 GHz & Turbo up to 4.40 GHz) 10 Cores','Intel Core i5 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Pre-installed Genuine Windows 10 Home OS','Intel Core i7 Processor (11th Gen)')
df.at[307,'Processor']='Intel Core i7 Processor (7th Gen)'
df.at[561,'Processor']='Intel Core i7 Processor (6th Gen)'
df.at[707,'Processor']='Intel Core i5 Processor (8th Gen)'
df.at[948,'Processor']='Intel Core i7 Processor (7th Gen)'
df['Processor']=df['Processor'].replace('Full HD LED Backlit IPS UWVA Display','Intel Core i5 Processor (7th Gen)')
df['Processor']=df['Processor'].replace('15.6 inches Full HD IPS Thin Bezel Display (60Hz, 45% NTSC Color Gamut)','Intel Core i5 Processor (9th Gen)')
df['Processor']=df['Processor'].replace('Stylish & Portable Thin and Light Foldable Laptop\n12th Gen Intel Evo� Core i7-1250U CPU with 10 cores and 4.7 GHz max frequency\n17.3 Inch 2.5K Foldable OLED, 0.2ms response time, 60Hz refresh rate, 500nits HDR peak brightness, 100% DCI-P3 color gamut, VESA CERTIFIED Display HDR True Black 500\nWorld�s first 17� foldable OLED laptop with Multiple versatile use cases possible: laptop, tablet, AiO, vertical, extended, etc.\n17.3� screen when unfolded, while just 8.7mm thin and 1.5kg in weight. MIL-STD 810H Military-grade durability\nASUS ErgoSense Bluetooth keyboard included in the box.\nTwo Thunderbolt 4 ports for external 4K display, 40 GB/s data transfer and fast charging','Intel Core i7 Processor (12th Gen)')

# %%
df.at[407,'Processor']='Intel Core i3 Processor (10th Gen)'
df['Processor']=df['Processor'].replace('Processor: Intel i7-1255U (Base- 3.50 GHz & Turbo up to 4.70 GHz) 10 Cores','Intel Core i7 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i3-1115G4 (Base- 1.70 GHz & Turbo up to 4.10 GHz) 2 Cores','Intel Core i3 Processor (11th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i7-11800H- (2.30 GHz up to 4.60 GHz) 16MB L3','Intel Core i7 Processor (11th Gen)')

# %%
df[df['Processor']=='Processor: Intel i7-11800H- (2.30 GHz up to 4.60 GHz) 16MB L3']
# Out:
# Empty DataFrame
# Columns: [Title, Rating, Price, Processor, RAM, Display Size, Storage Capacity, Brand, SSD_Capacity, Ram, Ram_Type, Display_Size, EMMC_Storage(in_GB), HDD_Storage(in_GB)]
# Index: []

# %%
df['Processor'].value_counts()
# Out:
# AMD Ryzen 7 Octa Core Processor                                                  87
# Intel Core i5 Processor (12th Gen)                                               77
# Intel Core i7 Processor (12th Gen)                                               73
# AMD Ryzen 5 Hexa Core Processor                                                  68
# Intel Core i3 Processor (11th Gen)                                               66
# Intel Core i5 Processor (11th Gen)                                               65
# Intel Core i5 Processor (10th Gen)                                               28
# AMD Ryzen 9 Octa Core Processor                                                  24
# Intel Core i3 Processor (10th Gen)                                               24
# Intel Core i7 Processor (11th Gen)                                               23
# Intel Core i7 Processor (10th Gen)                                               19
# ...

# %%
df.to_csv('file3.csv')
