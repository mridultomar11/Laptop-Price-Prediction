# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('file3.csv')
df.head()
# Out:
#    Unnamed: 0  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
#                                                                                                        Title  \
# 0  Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# 1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...
# 2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...
# 3  ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# 4  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
#
#    Rating    Price                           Processor            RAM  \
# 0  4.1     25685.0  Intel Celeron Dual Core Processor   8 GB DDR4 RAM
# 1  4.4     51990.0  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 2  4.2     38990.0  Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\mridu\AppData\Local\Temp\ipykernel_14040\3462665596.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Rating', 'Price', 'Processor', 'RAM',
#        'Display Size', 'Storage Capacity', 'Brand', 'SSD_Capacity', 'Ram',
#        'Ram_Type', 'Display_Size', 'EMMC_Storage(in_GB)',
#        'HDD_Storage(in_GB)'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#                                                                                                        Title  \
# 0  Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# 1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...
# 2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...
# 3  ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# 4  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
#
#    Rating    Price                           Processor            RAM  \
# 0  4.1     25685.0  Intel Celeron Dual Core Processor   8 GB DDR4 RAM
# 1  4.4     51990.0  Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 2  4.2     38990.0  Intel Core i3 Processor (11th Gen)  8 GB DDR4 RAM
# ...

# %%
df['Processor'].value_counts()
# Out:
# AMD Ryzen 7 Octa Core Processor                         92
# Intel Core i5 Processor (12th Gen)                      78
# AMD Ryzen 5 Hexa Core Processor                         74
# Intel Core i7 Processor (12th Gen)                      73
# Intel Core i3 Processor (11th Gen)                      68
# Intel Core i5 Processor (11th Gen)                      67
# Intel Core i5 Processor (10th Gen)                      32
# AMD Ryzen 9 Octa Core Processor                         27
# Intel Core i3 Processor (10th Gen)                      24
# Intel Core i7 Processor (11th Gen)                      23
# Intel Core i7 Processor (10th Gen)                      21
# Intel Core i9 Processor (12th Gen)                      19
# Intel Core i3 Processor (12th Gen)                      17
# Intel Core i5 Processor (8th Gen)                       16
# AMD Ryzen 5 Quad Core Processor                         15
# Intel Core i7 Processor (13th Gen)                      15
# ...

# %%
df['Processor']=df['Processor'].replace('Processor: Intel i3-1215U (0.9 GHz up to 4.40 GHz), 6 Cores & 10 MB CPU Cache','Intel Core i3 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i3-1215U (Base- 0.9 GHz & Turbo up to 4.40 GHz) 6 Cores','Intel Core i3 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i9-12900H (Base- 3.80 GHz & Turbo up to 5.0 GHz) 14 Cores','Intel Core i9 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Intel Hexa Core i5 Processor (10th Gen)','Intel Core i5 Processor (10th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i3-1215U (0.9 GHz up to 4.40 GHz), 6 Cores, 10MB CPU Cache','Intel Core i3 Processor (12th Gen)')
df['Processor']=df['Processor'].replace('Powered by 11th Gen Intel Evo Core i5 Processor','Intel Core i5 Processor (11th Gen)')
df['Processor']=df['Processor'].replace('Processor: Intel i3-1115G4 (Base- 1.7 GHz & Turbo up to 4.10 GHz) 2 Cores','Intel Core i3 Processor (11th Gen)')
df['Processor']=df['Processor'].replace('AMD Ryzen 9 Octa Core Processor (9th Gen)','AMD Ryzen 9 Octa Core Processor')
df['Processor']=df['Processor'].replace('NVIDIA GeForce GTX 1650','Intel Core i5 Processor (10th Gen)')
df['Processor']=df['Processor'].replace('AMD Ryzen 9 Octa Core Processor (10th Gen)','AMD Ryzen 9 Octa Core Processor')

# %%
df.at[175,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[445,'Processor']='Intel Core i5 Processor (10th Gen)'
df.at[573,'Processor']='Intel Core i7 Processor (10th Gen)'
df.at[278,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[350,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[488,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[545,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[403,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[517,'Processor']='AMD Ryzen 5 Dual Core Processor'
df.at[292,'Processor']='AMD Ryzen 7 Quad Core Processor'
df.at[106,'Processor']='Intel Core i5 Processor (12th Gen)'
df.at[299,'Processor']='Intel Core i3 Processor (12th Gen)'
df.at[380,'Processor']='Intel Core i7 Processor (10th Gen)'
df.at[438,'Processor']='Intel Core i9 Processor (10th Gen)'
df.at[116,'Processor']='AMD Ryzen 3 Quad Core Processor'
df.at[475,'Processor']='AMD Ryzen 5 Quad Core Processor'
df.at[745,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[717,'Processor']='AMD Ryzen 3 Dual Core Processor'
df.at[706,'Processor']='Intel Core i7 Processor (7th Gen)'
df.at[669,'Processor']='Intel Core i7 Processor (8th Gen)'
df.at[665,'Processor']='Intel Core i3 Processor (11th Gen)'
df.at[753,'Processor']='Intel Core i5 Processor (8th Gen)'
df.at[763,'Processor']='Intel Core i7 Processor (7th Gen)'
df.at[449,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[490,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[171,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[364,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[110,'Processor']='Intel Pentium Silver Processor'
df.at[131,'Processor']='Intel Core i3 Processor (11th Gen)'
df.at[249,'Processor']='Intel Core i7 Processor (10th Gen)'
df.at[264,'Processor']='AMD Ryzen 9 Octa Core Processor'
df.at[304,'Processor']='Intel Core i9 Processor (8th Gen)'
df.at[317,'Processor']='AMD Ryzen 5 Hexa Core Processor'
df.at[319,'Processor']='Intel Core i7 Processor (8th Gen)'
df.at[351,'Processor']='AMD Ryzen 7 Octa Core Processor'
df.at[599,'Processor']='Intel Celeron Dual Core Processor'
df.at[583,'Processor']='Intel Pentium Quad Core Processor'
df.at[151,'Processor']='Intel Celeron Dual Core Processor'

# %%
df['Processor'].value_counts()
# Out:
# AMD Ryzen 7 Octa Core Processor             93
# Intel Core i5 Processor (12th Gen)          78
# AMD Ryzen 5 Hexa Core Processor             75
# Intel Core i7 Processor (12th Gen)          73
# Intel Core i3 Processor (11th Gen)          69
# Intel Core i5 Processor (11th Gen)          67
# Intel Core i5 Processor (10th Gen)          32
# AMD Ryzen 9 Octa Core Processor             28
# Intel Core i3 Processor (10th Gen)          24
# Intel Core i7 Processor (11th Gen)          23
# Intel Core i7 Processor (10th Gen)          22
# Intel Core i9 Processor (12th Gen)          19
# Intel Core i3 Processor (12th Gen)          17
# Intel Core i5 Processor (8th Gen)           16
# Intel Celeron Dual Core Processor           15
# Intel Core i7 Processor (13th Gen)          15
# AMD Ryzen 5 Quad Core Processor             15
# Apple M2 Processor                          14
# AMD Ryzen 3 Quad Core Processor             12
# AMD Ryzen 3 Dual Core Processor             11
# ...

# %%
df.to_csv('file4.csv')
